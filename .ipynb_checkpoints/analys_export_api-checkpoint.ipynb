# %%
import pandas as pd
import requests

# %%
base_url = 'https://data-charts-api.hexlet.app'

visits_url = f'{base_url}/visits?begin=2023-03-01&end=2023-09-01'
registrations_url = f'{base_url}/registrations?begin=2023-03-01&end=2023-09-01'

visits_response = requests.get(visits_url)
registrations_response = requests.get(registrations_url)

# %%
visits_response.status_code, registrations_response.status_code
# Out:
# (200, 200)

# %%
visits_api = pd.DataFrame(visits_response.json())
registrations_api = pd.DataFrame(registrations_response.json())

# %%
visits_api = visits_api.rename(columns={'visit_id': 'uuid', 'datetime': 'date'})
registrations_api = registrations_api.rename(columns={'datetime': 'date'})

visits_api.to_csv('visits.csv', index=False)
registrations_api.to_csv('registrations.csv', index=False)

# %%
visits_api.head()
registrations_api.head()
# Out:
#                   date                               user_id  \
# 0  2023-03-01T07:40:13  2e0f6bb8-b029-4f45-a786-2b53990d37f1
# 1  2023-03-01T13:14:00  f007f97c-9d8b-48b5-af08-119bb8f6d9b6
# 2  2023-03-01T03:05:50  24ff46ae-32b3-4a74-8f27-7cf0b8f32f15
# 3  2023-03-01T00:04:47  3e9914e1-5d73-4c23-b25d-b59a3aeb2b60
# 4  2023-03-01T18:31:52  27f875fc-f8ce-4aeb-8722-0ecb283d0760
#
#                         email platform registration_type
# 0           ebyrd@example.org      web            google
# 1    knightgerald@example.org      web             email
# 2  cherylthompson@example.com      web             apple
# 3       halldavid@example.org      web             email
# 4        denise86@example.net      web            google

# %%
visits_api.info()
registrations_api.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 263459 entries, 0 to 263458
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   uuid        263459 non-null  str
#  1   platform    263459 non-null  str
#  2   user_agent  263459 non-null  str
#  3   date        263459 non-null  str
# dtypes: str(4)
# memory usage: 8.0 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 21836 entries, 0 to 21835
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               21836 non-null  str
#  1   user_id            21836 non-null  str
#  2   email              21836 non-null  str
#  3   platform           21836 non-null  str
#  4   registration_type  21836 non-null  str
# dtypes: str(5)
# memory usage: 853.1 KB

# %%
visits_api.describe(include='all')
registrations_api.describe(include='all')
# Out:
#                        date                               user_id  \
# count                 21836                                 21836
# unique                21821                                 21836
# top     2023-03-01T09:53:07  2e0f6bb8-b029-4f45-a786-2b53990d37f1
# freq                      2                                     1
#
#                      email platform registration_type
# count                21836    21836             21836
# unique               20868        3                 4
# top     ujones@example.com  android             email
# freq                     6    10582              8996

# %%
visits_api
# Out:
#                                         uuid platform  \
# 0       92e2498e-3202-4286-a48e-a4abe5131313      web
# 1       92e2498e-3202-4286-a48e-a4abe5131313      web
# 2       92e2498e-3202-4286-a48e-a4abe5131313      web
# 3       0919c209-9aa2-4c11-ba6f-6a15669954cf      web
# 4       0919c209-9aa2-4c11-ba6f-6a15669954cf      web
# ...                                      ...      ...
# 263454  b8622392-8228-4760-a665-0b346d445484      web
# 263455  b8622392-8228-4760-a665-0b346d445484      web
# 263456  22e87038-5748-4f49-8df0-2ae103f0d77c      web
# 263457  22e87038-5748-4f49-8df0-2ae103f0d77c      web
# 263458  22e87038-5748-4f49-8df0-2ae103f0d77c      web
#
#                                                user_agent                 date
# 0       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-06-01T11:12:38
# 1       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-05-30T13:44:46
# 2       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-05-29T04:37:54
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...  2023-06-01T05:58:14
# 4       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...  2023-05-29T01:22:31
# ...                                                   ...                  ...
# 263454  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...  2023-06-01T03:30:10
# 263455  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...  2023-05-30T00:03:08
# 263456  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  2023-06-01T02:37:54
# 263457  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  2023-05-30T05:31:28
# 263458  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  2023-05-29T18:55:18
#
# [263459 rows x 4 columns]
